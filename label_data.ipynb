# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv', sep='\t')

# %%
df = df[df['Thành công'] == True]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 459 entries, 21 to 6008
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Loại cửa hàng                     459 non-null    object
#  1   Tên cửa hàng                      459 non-null    object
#  2   Địa chỉ cửa hàng                  459 non-null    object
#  3   Số sao trên ShopeeFood            459 non-null    float64
#  4   Số lượt đánh giá trên ShopeeFood  459 non-null    object
#  5   Thời gian mở cửa                  459 non-null    object
#  6   Giá thấp nhất                     459 non-null    int64
#  7   Giá cao nhất                      459 non-null    int64
#  8   Phí dịch vụ                       459 non-null    object
#  9   Số sao trên Foody                 459 non-null    float64
#  10  Số lượt đánh giá trên Foody       459 non-null    int64
#  11  Cửa hàng có menu                  459 non-null    int64
#  12  Tổng số lượng sản phẩm            459 non-null    int64
#  13  Giá trung bình                    459 non-null    float64
#  14  Thành công                        459 non-null    bool
#  15  Quận                              459 non-null    object
#  16  Khoảng giá                        459 non-null    object
#  17  Số lượng món                      459 non-null    object
#  18  Khoảng thời gian mở cửa           459 non-null    float64
# dtypes: bool(1), float64(4), int64(5), object(9)
# memory usage: 68.6+ KB

# %% [markdown]
# ## Thống kê các quán ăn thành công dựa trên các tiêu chí

# %% [markdown]
# ### Loại cửa hàng

# %%
df['Loại cửa hàng'].value_counts().plot.barh()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Khu vực hoạt động (quận)

# %%
df['Quận'].value_counts().plot.barh()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Khoảng giá

# %%
df['Khoảng giá'].value_counts().plot.barh()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Số lượng món trong thực đơn

# %%
df['Số lượng món'].value_counts().plot.barh()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Thời gian mở cửa

# %%
df['Khoảng thời gian mở cửa'].value_counts().plot.barh()
# Out:
# <AxesSubplot: >
