# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
df_1 = pd.read_csv('./Data/shopeefood_store_1.txt', sep="\t")
df_1_n = pd.read_csv('./Data/shopeefood_store_1_n.txt', sep="\t")
df_2 = pd.read_csv('./Data/shopeefood_store_2.txt', sep="\t")
df_3 = pd.read_csv('./Data/shopeefood_store_3.txt', sep="\t")
df_4 = pd.read_csv('./Data/shopeefood_store_4.txt', sep="\t")
df_5 = pd.read_csv('./Data/shopeefood_store_5.txt', sep="\t")
df_6_n = pd.read_csv('./Data/shopeefood_store_6_n.txt', sep="\t")
df_7_n = pd.read_csv('./Data/shopeefood_store_7_n.txt', sep="\t")
df_8 = pd.read_csv('./Data/shopeefood_store_8.txt', sep="\t")
df_8_n = pd.read_csv('./Data/shopeefood_store_8_n.txt', sep="\t")

# %%
frames = [df_1, df_1_n, df_2, df_3, df_4, df_5, df_6_n, df_7_n, df_8, df_8_n]
df = pd.concat(frames)
df.drop_duplicates(subset = ['Tên cửa hàng'],inplace = True)
df.reset_index(drop = True, inplace = True)
df
# Out:
#                    Loại cửa hàng  \
# 0                        Quán ăn
# 1                        Quán ăn
# 2                        Quán ăn
# 3                   Café/Dessert
# 4                        Quán ăn
# ...                          ...
# 6188   Café/Dessert, Shop Online
# 6189                     Quán ăn
# 6190  Ăn vặt/vỉa hè, Shop Online
# 6191               Ăn vặt/vỉa hè
# 6192                     Quán ăn
#
#                                            Tên cửa hàng  \
# 0          Hủ Tiếu Nam Vang Hòa Phát - Nguyễn Thanh Sơn
# 1     HỦ TIẾU NAM VANG NAM KIỆT - Hủ Tiếu Nam Vang -...
# 2                        Dose Coffee - Nguyễn Thanh Sơn
# 3                               Phúc Long Đảo Kim Cương
# 4                          Lẩu Bò Anh Ba - Đường Số 104
# ...                                                 ...
# 6188  ROBINA - Sinh Tố &amp; Nước Ép - Nguyễn Bình (...
# 6189                       Thắm - Gỏi Gà Vịt &amp; Cháo
# 6190  Thế Giới Ăn Vặt - Trà Sữa &amp; Ăn Vặt - Lê Vă...
# 6191    KATI MILK TEA - Trà Sữa, Sinh Tố - Lê Văn Lương
# 6192                                     Cháo Vịt Út Be
#
#                                        Địa chỉ cửa hàng  \
# 0     36A Nguyễn Thanh Sơn, P. Thạnh Mỹ Lợi, Thủ Đức...
# 1     38A Nguyễn Thanh Sơn, P. Thạnh Mỹ Lợi, Thủ Đức...
# 2     11 Nguyễn Thanh Sơn, P. Thạnh Mỹ Lợi, Thủ Đức,...
# 3     Khu Thương Mại B2.2B, Tầng B2, Tháp Bora Bora,...
# 4     21 Đường Số 104, P. Thạnh Mỹ Lợi, Thủ Đức, TP....
# ...                                                 ...
# 6188  299 Nguyễn Bình, Ấp 1, X. Nhơn Đức, Nhà Bè, TP...
# 6189  1038B Lê Văn Lương, P. Phước Kiển, Nhà Bè, TP....
# 6190  724/28 Lê Văn Lương, X. Phước Kiểng, Nhà Bè, T...
# 6191  799 Lê Văn Lương Ấp 5, Xã Phước Kiểng, Nhà Bè,...
# 6192  237 Lê Văn Lương, P. Phước Kiểng, Nhà Bè, TP. HCM
#
#       Số sao trên ShopeeFood Số lượt đánh giá trên ShopeeFood  \
# 0                        4.5                             100+
# 1                        3.5                                7
# 2                        5.0                              10+
# 3                        4.5                             100+
# 4                        4.5                             100+
# ...                      ...                              ...
# 6188                     4.5                                7
# 6189                     4.5                              10+
# 6190                     4.0                                9
# 6191                     4.5                                6
# 6192                     4.5                              10+
#
#      Thời gian mở cửa Giá thấp nhất Giá cao nhất       Phí dịch vụ  \
# 0       06:16 - 20:40        30,000       50,000              0.0%
# 1       06:00 - 20:30             0            0              0.0%
# 2       07:00 - 20:30             0            0              0.0%
# 3       07:00 - 20:30        30,000      100,000              0.0%
# 4       09:30 - 22:30        10,000      300,000              0.0%
# ...               ...           ...          ...               ...
# 6188    09:00 - 21:30             0            0              0.0%
# 6189    15:15 - 21:30        20,000      180,000              0.0%
# 6190    09:30 - 21:30             0            0              0.0%
# 6191    15:00 - 22:00             0            0              0.0%
# 6192    11:00 - 17:00        40,000      200,000  ShopeeFood</span
#
#      Số sao trên Foody Số lượt đánh giá trên Foody
# 0     <span>_._</span>                           0
# 1     <span>_._</span>                           0
# 2     <span>_._</span>                           0
# 3     <span>_._</span>                           0
# 4     <span>_._</span>                           0
# ...                ...                         ...
# 6188                 0                           0
# 6189  <span>_._</span>                           0
# 6190  <span>_._</span>                           0
# 6191  <span>_._</span>                           0
# 6192               7.4                          13
#
# [6193 rows x 11 columns]

# %%
#Xử lý ngoại lệ số sao
df['Số sao trên Foody'] = df['Số sao trên Foody'].replace('<span>_._</span>','0')
#Xử lý tên cửa hàng
for i in range(len(df['Tên cửa hàng'])):
    if df['Tên cửa hàng'][i].find('&amp;'):
        df['Tên cửa hàng'][i] = df['Tên cửa hàng'][i].replace('&amp;','Và')
#Xử lý lượt đánh giá
df['Số lượt đánh giá trên ShopeeFood'] = df['Số lượt đánh giá trên ShopeeFood'].apply(lambda x: '< 100' if x not in ['100+','500+','999+'] else x)
#Xử lý Phí dịch vụ
df['Phí dịch vụ'] = df['Phí dịch vụ'].apply(lambda x: 'Unknown' if x == 'ShopeeFood</span' else x)
df['Số sao trên Foody'] = df['Số sao trên Foody'].astype('float64')
df['Số lượt đánh giá trên Foody'] = df['Số lượt đánh giá trên Foody'].replace(',','', regex=True).astype(int)
df['Giá thấp nhất'] = df['Giá thấp nhất'].replace(',','', regex=True).astype(int)
df['Giá cao nhất'] = df['Giá cao nhất'].replace(',','', regex=True).astype(int)
# Out:
# C:\Users\Long\AppData\Local\Temp\ipykernel_10400\1959583923.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tên cửa hàng'][i] = df['Tên cửa hàng'][i].replace('&amp;','Và')

# %%
df
# Out:
#                    Loại cửa hàng  \
# 0                        Quán ăn
# 1                        Quán ăn
# 2                        Quán ăn
# 3                   Café/Dessert
# 4                        Quán ăn
# ...                          ...
# 6188   Café/Dessert, Shop Online
# 6189                     Quán ăn
# 6190  Ăn vặt/vỉa hè, Shop Online
# 6191               Ăn vặt/vỉa hè
# 6192                     Quán ăn
#
#                                            Tên cửa hàng  \
# 0          Hủ Tiếu Nam Vang Hòa Phát - Nguyễn Thanh Sơn
# 1     HỦ TIẾU NAM VANG NAM KIỆT - Hủ Tiếu Nam Vang -...
# 2                        Dose Coffee - Nguyễn Thanh Sơn
# 3                               Phúc Long Đảo Kim Cương
# 4                          Lẩu Bò Anh Ba - Đường Số 104
# ...                                                 ...
# 6188  ROBINA - Sinh Tố Và Nước Ép - Nguyễn Bình (khô...
# 6189                          Thắm - Gỏi Gà Vịt Và Cháo
# 6190  Thế Giới Ăn Vặt - Trà Sữa Và Ăn Vặt - Lê Văn L...
# 6191    KATI MILK TEA - Trà Sữa, Sinh Tố - Lê Văn Lương
# 6192                                     Cháo Vịt Út Be
#
#                                        Địa chỉ cửa hàng  \
# 0     36A Nguyễn Thanh Sơn, P. Thạnh Mỹ Lợi, Thủ Đức...
# 1     38A Nguyễn Thanh Sơn, P. Thạnh Mỹ Lợi, Thủ Đức...
# 2     11 Nguyễn Thanh Sơn, P. Thạnh Mỹ Lợi, Thủ Đức,...
# 3     Khu Thương Mại B2.2B, Tầng B2, Tháp Bora Bora,...
# 4     21 Đường Số 104, P. Thạnh Mỹ Lợi, Thủ Đức, TP....
# ...                                                 ...
# 6188  299 Nguyễn Bình, Ấp 1, X. Nhơn Đức, Nhà Bè, TP...
# 6189  1038B Lê Văn Lương, P. Phước Kiển, Nhà Bè, TP....
# 6190  724/28 Lê Văn Lương, X. Phước Kiểng, Nhà Bè, T...
# 6191  799 Lê Văn Lương Ấp 5, Xã Phước Kiểng, Nhà Bè,...
# 6192  237 Lê Văn Lương, P. Phước Kiểng, Nhà Bè, TP. HCM
#
#       Số sao trên ShopeeFood Số lượt đánh giá trên ShopeeFood  \
# 0                        4.5                             100+
# 1                        3.5                            < 100
# 2                        5.0                            < 100
# 3                        4.5                             100+
# 4                        4.5                             100+
# ...                      ...                              ...
# 6188                     4.5                            < 100
# 6189                     4.5                            < 100
# 6190                     4.0                            < 100
# 6191                     4.5                            < 100
# 6192                     4.5                            < 100
#
#      Thời gian mở cửa  Giá thấp nhất  Giá cao nhất Phí dịch vụ  \
# 0       06:16 - 20:40          30000         50000        0.0%
# 1       06:00 - 20:30              0             0        0.0%
# 2       07:00 - 20:30              0             0        0.0%
# 3       07:00 - 20:30          30000        100000        0.0%
# 4       09:30 - 22:30          10000        300000        0.0%
# ...               ...            ...           ...         ...
# 6188    09:00 - 21:30              0             0        0.0%
# 6189    15:15 - 21:30          20000        180000        0.0%
# 6190    09:30 - 21:30              0             0        0.0%
# 6191    15:00 - 22:00              0             0        0.0%
# 6192    11:00 - 17:00          40000        200000     Unknown
#
#       Số sao trên Foody  Số lượt đánh giá trên Foody
# 0                   0.0                            0
# 1                   0.0                            0
# 2                   0.0                            0
# 3                   0.0                            0
# 4                   0.0                            0
# ...                 ...                          ...
# 6188                0.0                            0
# 6189                0.0                            0
# 6190                0.0                            0
# 6191                0.0                            0
# 6192                7.4                           13
#
# [6193 rows x 11 columns]

# %%
df.dtypes
# Out:
# Loại cửa hàng                        object
# Tên cửa hàng                         object
# Địa chỉ cửa hàng                     object
# Số sao trên ShopeeFood              float64
# Số lượt đánh giá trên ShopeeFood     object
# Thời gian mở cửa                     object
# Giá thấp nhất                         int32
# Giá cao nhất                          int32
# Phí dịch vụ                          object
# Số sao trên Foody                   float64
# Số lượt đánh giá trên Foody           int32
# dtype: object

# %%
num_cols = ['Số sao trên ShopeeFood','Số sao trên Foody','Số lượt đánh giá trên Foody','Giá thấp nhất','Giá cao nhất']
pd.set_option('display.max_colwidth', 200) # Để nhìn rõ hơn
cat_cols = list(set(df.columns) - set(num_cols))
df_c = df[cat_cols]
def missing_ratio(df):
    return (df.isna().mean() * 100).round(1)
def num_values(df):
    return df.nunique()
def value_ratios(c):
    return dict((c.value_counts(normalize=True) * 100).round(1))
df_c.agg([missing_ratio, num_values, value_ratios])
# Out:
#                                                                                                                                                                                                          Loại cửa hàng  \
# missing_ratio                                                                                                                                                                                                      0.0
# num_values                                                                                                                                                                                                          55
# value_ratios   {'Quán ăn': 42.9, 'Café/Dessert': 23.5, 'Ăn vặt/vỉa hè': 13.0, 'Nhà hàng': 5.2, 'Shop Online': 4.9, 'Tiệm bánh': 3.0, 'Ăn chay': 1.8, 'Café/Dessert, Quán ăn': 0.9, 'Quán ăn, Ăn vặt/vỉa hè': 0.5, '...
#
#                                                                                                                                                                                                       Địa chỉ cửa hàng  \
# missing_ratio                                                                                                                                                                                                      0.0
# num_values                                                                                                                                                                                                        5821
# value_ratios   {'372/17 Cách Mạng Tháng 8, P. 10, Quận 3, TP. HCM': 0.3, '213/9 Nguyễn Gia Trí, P. 25, Bình Thạnh, TP. HCM': 0.2, '28 Phan Phú Tiên, P. 10, Quận 5, TP. HCM': 0.2, '90 Trần Khắc Chân, P. 9, Phú Nh...
#
#                                        Số lượt đánh giá trên ShopeeFood  \
# missing_ratio                                                       0.0
# num_values                                                            4
# value_ratios   {'< 100': 40.7, '999+': 27.6, '100+': 21.9, '500+': 9.8}
#
#                                                                                                                                                                                                       Thời gian mở cửa  \
# missing_ratio                                                                                                                                                                                                      0.0
# num_values                                                                                                                                                                                                        1318
# value_ratios   {'00:00 - 23:59': 4.3, '09:00 - 22:00': 3.3, '10:00 - 22:00': 2.7, '09:00 - 21:00': 2.5, '08:00 - 22:00': 2.4, '07:00 - 22:00': 2.3, '07:00 - 21:00': 2.1, '10:00 - 21:00': 1.9, '08:00 - 21:00': 1....
#
#                                                                                                                                                                                                           Tên cửa hàng  \
# missing_ratio                                                                                                                                                                                                      0.0
# num_values                                                                                                                                                                                                        6193
# value_ratios   {'Hủ Tiếu Nam Vang Hòa Phát - Nguyễn Thanh Sơn': 0.0, 'Thành Đạt - Hủ Tiếu Nam Vang - Quốc Lộ 50': 0.0, 'Cháo Dinh Dưỡng Wow - 110 Lê Văn Lương (không có menu)': 0.0, 'Cơm Gà Đệ Nhất - Nguyễn Thị ...
#
#                                                Phí dịch vụ
# missing_ratio                                          0.0
# num_values                                               3
# value_ratios   {'0.0%': 94.8, 'Unknown': 5.2, '2.0%': 0.0}

# %%
df_n = df[num_cols]
def missing_ratio(df):
    return (df.isna().mean() * 100).round(1)
def lower_quartile(df):
    return df.quantile(0.25).round(1)
def median(df):
    return df.quantile(0.5).round(1)
def upper_quartile(df):
    return df.quantile(0.75).round(1)
df_n.agg([missing_ratio, 'min', lower_quartile, median, upper_quartile, 'max'])
# Out:
#                 Số sao trên ShopeeFood  Số sao trên Foody  \
# missing_ratio                      0.0                0.0
# min                                0.0                0.0
# lower_quartile                     4.5                0.0
# median                             4.5                5.6
# upper_quartile                     4.5                7.8
# max                                5.0               10.0
#
#                 Số lượt đánh giá trên Foody  Giá thấp nhất  Giá cao nhất
# missing_ratio                           0.0            0.0           0.0
# min                                     0.0            0.0           0.0
# lower_quartile                          0.0        10000.0       30000.0
# median                                  1.0        19000.0       50000.0
# upper_quartile                         10.0        30000.0       99000.0
# max                                  1458.0       400000.0     6000000.0

# %%
def pre_plot(df, name):
    return df[name].value_counts()[:5].index, df[name].value_counts()[:5].values

# %%
time, num_time = pre_plot(df, 'Thời gian mở cửa')
plt.barh(time, num_time)
plt.title('Thời gian mở cửa')
plt.show()

# %%
star, num_star = pre_plot(df, 'Số lượt đánh giá trên ShopeeFood')
plt.barh(star, num_star)
plt.title('Số lượt đánh giá trên ShopeeFood')
plt.show()

# %%
service, service_num = pre_plot(df, 'Phí dịch vụ')
plt.barh(service, service_num)
plt.title('Phí dịch vụ')
plt.show()

# %%
kind, kind_num = pre_plot(df, 'Loại cửa hàng')
plt.barh(kind, kind_num)
plt.title('Loại cửa hàng')
plt.show()

# %%
plt.bar(df['Số sao trên ShopeeFood'].value_counts().index, df['Số sao trên ShopeeFood'].value_counts().values, width = 0.5)
plt.title('Số sao trên ShopeeFood')
plt.show()

# %%
f_star = df['Số sao trên Foody']
f_star.replace(0, np.nan, inplace = True)
plt.bar(f_star.value_counts().index, f_star.value_counts().values, width = 0.1)
plt.title('Số sao trên Foody')
plt.show()

# %%
#Số lượt đánh giá trên Foody
f_rev = df['Số lượt đánh giá trên Foody']
f_rev.replace(0, np.nan, inplace = True)
plt.bar(f_rev.value_counts().index, f_rev.value_counts().values, width = 10)
plt.title('Số lượt đánh giá trên Foody')
plt.show()

# %%
df_m = pd.read_csv('./menuStore/Hủ Tiếu Nam Vang Hòa Phát - Nguyễn Thanh Sơn', sep=",")
df_m[['Food','Price']]
# Out:
#                                        Food   Price
# 0                              Mì vàng nước  59,000
# 1                             Đặc biệt nước  69,000
# 2   hủ tíu khô em bé.  (thịt bằm trứng cút)  30,000
# 3                             Tô, muỗng đũa       1
# 4      Tô Em Bé Nước ( thịt bằm Trứng cút )  30,000
# 5                                  Cocacola  15,000
# 6                    nước dâu ngâm nhà làm   25,000
# 7                                  7 Up lon  15,000
# 8                                 Nước suối  10,000
# 9                             Bánh thêm khô  20,000
# 10                           Bánh thêm nước  20,000
